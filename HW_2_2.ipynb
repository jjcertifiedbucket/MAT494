# %% [markdown]
# <a href="https://colab.research.google.com/github/justinsantacruz/MAT494/blob/main/HW_2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import pearsonr

# %%
data = pd.read_csv("/Users/Justin/Desktop/FALL2022/MAT494/Dataset/HepatitisCdata.csv")

data.shape
# Out:
# (615, 14)

# %%
new_data = data.drop(columns = 'Unnamed: 0')
new_data.head()
# Out:
#         Category  Age Sex   ALB   ALP   ALT   AST   BIL    CHE  CHOL   CREA  \
# 0  0=Blood Donor   32   m  38.5  52.5   7.7  22.1   7.5   6.93  3.23  106.0
# 1  0=Blood Donor   32   m  38.5  70.3  18.0  24.7   3.9  11.17  4.80   74.0
# 2  0=Blood Donor   32   m  46.9  74.7  36.2  52.6   6.1   8.84  5.20   86.0
# 3  0=Blood Donor   32   m  43.2  52.0  30.6  22.6  18.9   7.33  4.74   80.0
# 4  0=Blood Donor   32   m  39.2  74.1  32.6  24.8   9.6   9.15  4.32   76.0
#
#     GGT  PROT
# 0  12.1  69.0
# 1  15.6  76.5
# 2  33.2  79.3
# 3  33.8  75.7
# 4  29.9  68.7

# %%
new_data.describe()
# Out:
#               Age         ALB         ALP         ALT         AST         BIL  \
# count  615.000000  614.000000  597.000000  614.000000  615.000000  615.000000
# mean    47.408130   41.620195   68.283920   28.450814   34.786341   11.396748
# std     10.055105    5.780629   26.028315   25.469689   33.090690   19.673150
# min     19.000000   14.900000   11.300000    0.900000   10.600000    0.800000
# 25%     39.000000   38.800000   52.500000   16.400000   21.600000    5.300000
# 50%     47.000000   41.950000   66.200000   23.000000   25.900000    7.300000
# 75%     54.000000   45.200000   80.100000   33.075000   32.900000   11.200000
# max     77.000000   82.200000  416.600000  325.300000  324.000000  254.000000
#
#               CHE        CHOL         CREA         GGT        PROT
# count  615.000000  605.000000   615.000000  615.000000  614.000000
# mean     8.196634    5.368099    81.287805   39.533171   72.044137
# ...

# %%
bd = new_data.loc[data.Category == "0=Blood Donor"]

corr_mat_bd = bd.corr().round(2)
corr_mat_bd

plt.figure(figsize = (15,10))
plot = sns.heatmap(bd.corr().round(2), annot = True)
plot.set_title("Blood Donor")
# Out:
# Text(0.5, 1.0, 'Blood Donor')

# %%
new_data.corr()
# Out:
#            Age       ALB       ALP       ALT       AST       BIL       CHE  \
# Age   1.000000 -0.197498  0.173340 -0.006021  0.088666  0.032492 -0.075093
# ALB  -0.197498  1.000000 -0.141584  0.001606 -0.193450 -0.221651  0.375878
# ALP   0.173340 -0.141584  1.000000  0.214480  0.063948  0.056078  0.033753
# ALT  -0.006021  0.001606  0.214480  1.000000  0.273326 -0.038469  0.147000
# AST   0.088666 -0.193450  0.063948  0.273326  1.000000  0.312231 -0.208536
# BIL   0.032492 -0.221651  0.056078 -0.038469  0.312231  1.000000 -0.333172
# CHE  -0.075093  0.375878  0.033753  0.147000 -0.208536 -0.333172  1.000000
# CHOL  0.125641  0.208248  0.125429  0.068947 -0.209970 -0.180370  0.425456
# CREA -0.022296 -0.001573  0.149832 -0.043025 -0.021387  0.031224 -0.011157
# GGT   0.153087 -0.155749  0.454630  0.248114  0.491263  0.217024 -0.110345
# PROT -0.153668  0.557197 -0.055109  0.094730  0.040071 -0.047638  0.295427
#
#           CHOL      CREA       GGT      PROT
# ...
